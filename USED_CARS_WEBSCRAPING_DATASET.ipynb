# %%
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver 
from selenium import webdriver

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(4)

url = "https://www.theaa.com/used-cars/supermini-for-sale"
driver.get(url)
time.sleep(6)

# %%
brand = []

for i in range(1,500):
    name = driver.find_elements_by_xpath("//div[@class= 'vl-list']/div/h3")
    for i in name:
        brand.append(i.text)
driver.find_element_by_xpath("//div[@class= 'container']/div/button[2]").click()
time.sleep(2)

# %%
price = []

for i in range(1,500):
    pri = driver.find_elements_by_xpath("//div[@class= 'vl-list']/div/div/div/div/strong")
    for i in pri:
        price.append(i.text.replace('£','').replace(',', ''))
driver.find_element_by_xpath("//div[@class= 'container']/div/button[2]").click()
time.sleep(2)

# %%
year = []

for i in range(1,500):
    yea = driver.find_elements_by_xpath("//div[@class= 'vl-list']/div/div/div/ul/li[1]")
    for i in yea:
        year.append(i.text)
driver.find_element_by_xpath("//div[@class= 'container']/div/button[2]").click()
time.sleep(2)

# %%
fuel = []

for i in range(1,500):
    fue = driver.find_elements_by_xpath("//div[@class= 'vl-list']/div/div/div/ul/li[5]")
    for i in fue:
        fuel.append(i.text)
driver.find_element_by_xpath("//div[@class= 'container']/div/button[2]").click()
time.sleep(2)

# %%
trans = []

for i in range(1,500):
    tra = driver.find_elements_by_xpath("//div[@class= 'vl-list']/div/div/div/ul/li[7]")
    for i in tra:
        trans.append(i.text)
driver.find_element_by_xpath("//div[@class= 'container']/div/button[2]").click()
time.sleep(2)

# %%
run = []

for i in range(1,500):
    runn = driver.find_elements_by_xpath("//div[@class= 'vl-list']/div/div/div/ul/li[3]")
    for i in runn:
        run.append(i.text.replace('miles','').replace(',', ''))
driver.find_element_by_xpath("//div[@class= 'container']/div/button[2]").click()
time.sleep(2)

# %%
loc = []

for i in range(1,500):
    loca = driver.find_elements_by_xpath("//div[@class= 'vl-location']")
    for i in loca:
        loc.append(i.text)
driver.find_element_by_xpath("//div[@class= 'container']/div/button[2]").click()
time.sleep(2)

# %%
print(len(brand),len(price),len(year),len(fuel),len(trans),len(run),len(loc))
# Out:
# 9980 9980 9980 9980 9980 9980 9980

# %%
Usedcar = pd.DataFrame({'Brand': brand,'Price':price,'Year':year,'Fuel':fuel,'Transmission':trans,'Running KM':run,'Location':loc})
Usedcar
# Out:
#                                           Brand  Price  Year      Fuel  \
# 0              Mercedes-Benz A Class 2L AMG A35  26925  2018    Petrol
# 1                Toyota Yaris 1.6L GR Circuit T  26850  2015    Petrol
# 2                Toyota Yaris 1.6L GR Circuit T  26725  2020    Petrol
# 3                         BMW 1 Series 2L M135i  26400  2019    Petrol
# 4                         BMW 1 Series 2L M135i  26375  2018    Petrol
# ...                                         ...    ...   ...       ...
# 9975  Mercedes-Benz A Class 1.5L AMG Line A180d  25500  2020    Petrol
# 9976   Mercedes-Benz A Class 1.3L AMG Line A180  25500  2020    Petrol
# 9977   Mercedes-Benz A Class 1.3L AMG Line A200  25425  2019    Petrol
# 9978  Mercedes-Benz A Class 1.5L AMG Line A180d  25425  2020  Electric
# 9979   Mercedes-Benz A Class 1.3L AMG Line A200  25350  2019    Diesel
#
#      Transmission Running KM Location
# 0       Automatic      8015    London
# 1       Automatic     11718    London
# 2          Manual     24308    London
# 3       Automatic     10849    London
# 4       Automatic     21716    London
# ...           ...        ...      ...
# 9975    Automatic     11605    London
# 9976    Automatic      8307    London
# 9977    Automatic      2743    London
# 9978    Automatic     11250    London
# 9979       Manual     13398    London
#
# [9980 rows x 7 columns]

# %%
Usedcar.to_excel("UsedCar.xlsx")
